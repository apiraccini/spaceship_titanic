# %% [markdown]
# # Compare several models

# %% [markdown]
# ## Setup

# %%
import platform; print(platform.platform())
import sys; print("Python", sys.version)
# Out:
# Windows-10-10.0.19045-SP0
# Python 3.10.5 (tags/v3.10.5:f377153, Jun  6 2022, 16:14:13) [MSC v.1929 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd

from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('../data/final/train.csv')
test = pd.read_csv('../data/final/test.csv')

train.sample(5)
# Out:
#      HomePlanet CryoSleep  Destination   Age    VIP  RoomService  FoodCourt  \
# 3013      Earth     False  TRAPPIST-1e 26.00  False         0.00      56.00
# 3844     Europa     False  TRAPPIST-1e 45.00  False         0.00    2524.00
# 7925      Earth     False  TRAPPIST-1e 21.00  False        32.00     640.00
# 4948      Earth     False  TRAPPIST-1e 29.00  False         0.00      10.00
# 5934       Mars      True  TRAPPIST-1e 42.00  False         0.00       0.00
#
#       ShoppingMall    Spa  VRDeck  Transported  Group_count Cabin_deck  \
# 3013        322.00   6.00  243.00         True            1          G
# 3844          0.00 166.00    1.00         True            2          B
# 7925          0.00   0.00    0.00         True            1          F
# 4948          0.00 594.00  120.00        False            1          F
# 5934          0.00   0.00    0.00         True            1          F
#
#      Cabin_side
# 3013          P
# 3844          P
# 7925          S
# 4948          S
# 5934          P

# %%
TARGET = 'Transported'
FEATURES = [col for col in train.columns if col not in [TARGET]]

numerical = train[FEATURES].select_dtypes(include=np.number).columns
categorical = train[FEATURES].select_dtypes(exclude=np.number).columns

train[numerical] = train[numerical].astype(float)
train[categorical] = train[categorical].astype(str)

print(f'Target: {TARGET}')
print(f'Fetaures:\n\tnumerical: {numerical.to_list()}\n\tcategorical:{categorical.to_list()}')
print(f'Shapes:\n\ttrain: {train.shape}\n\ttest: {test.shape}')
# Out:
# Target: Transported
# Fetaures:
# 	numerical: ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Group_count']
# 	categorical:['HomePlanet', 'CryoSleep', 'Destination', 'VIP', 'Cabin_deck', 'Cabin_side']
# Shapes:
# 	train: (8693, 14)
# 	test: (4277, 13)

# %% [markdown]
# ## Models

# %%
# data splitting
x, x_val, y, y_val = train_test_split(
    train[FEATURES], # lazypredict should have preprocessing but it doesn't work
    train[TARGET].astype(int),
    train_size=0.8, random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

numerical_preproc = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="mean")),
        ("scaler", StandardScaler())
    ]
)

categorical_preproc = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
        ("encoding", OneHotEncoder(handle_unknown="ignore", sparse=False)),
    ]
)

preprocessor = ColumnTransformer([
    ('numerical', numerical_preproc, numerical.to_list()),
    ('categorical', categorical_preproc, categorical.to_list())])

preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Age', 'RoomService', 'FoodCourt',
#                                   'ShoppingMall', 'Spa', 'VRDeck',
#                                   'Group_count']),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('encoding',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['HomePlanet', 'CryoSleep', 'Destination',
#                                   'VIP', 'Cabin_deck', 'Cabin_side'])])

# %%
x = preprocessor.fit_transform(x)
x_val = preprocessor.transform(x_val)

# %%
# many regressors with default parameters (preprocessing steps are included)
clf = LazyClassifier(
    verbose=0,
    ignore_warnings=True,
    custom_metric=None,
    predictions=True,
    random_state=42,
    classifiers='all'
)

models, predictions = clf.fit(x, x_val, y, y_val)
# Out:
# 100%|██████████| 29/29 [00:35<00:00,  1.24s/it]

# %%
pd.reset_option('display.float_format')
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                    0.7918             0.7917   0.7917    0.7918
# SVC                              0.7901             0.7901   0.7901    0.7901
# NuSVC                            0.7872             0.7873   0.7873    0.7872
# LGBMClassifier                   0.7867             0.7865   0.7865    0.7866
# AdaBoostClassifier               0.7849             0.7845   0.7845    0.7845
# LogisticRegression               0.7815             0.7812   0.7812    0.7813
# CalibratedClassifierCV           0.7803             0.7801   0.7801    0.7802
# LinearSVC                        0.7803             0.7801   0.7801    0.7802
# RandomForestClassifier           0.7798             0.7800   0.7800    0.7797
# BaggingClassifier                0.7780             0.7784   0.7784    0.7777
# LinearDiscriminantAnalysis       0.7602             0.7606   0.7606    0.7598
# RidgeClassifier                  0.7602             0.7606   0.7606    0.7598
# RidgeClassifierCV                0.7602             0.7606   0.7606    0.7598
# SGDClassifier                    0.7608             0.7601   0.7601    0.7595
# ExtraTreesClassifier             0.7585             0.7588   0.7588    0.7582
# KNeighborsClassifier             0.7579             0.7579   0.7579    0.7579
# NearestCentroid                  0.7487             0.7494   0.7494    0.7477
# GaussianNB                       0.7499             0.7485   0.7485    0.7448
# BernoulliNB                      0.7453             0.7460   0.7460    0.7440
# LabelSpreading                   0.7395             0.7393   0.7393    0.7394
# LabelPropagation                 0.7395             0.7393   0.7393    0.7393
# Perceptron                       0.7269             0.7275   0.7275    0.7259
# QuadraticDiscriminantAnalysis    0.7274             0.7264   0.7264    0.7245
# DecisionTreeClassifier           0.7251             0.7251   0.7251    0.7251
# ExtraTreeClassifier              0.7056             0.7055   0.7055    0.7056
# PassiveAggressiveClassifier      0.6849             0.6855   0.6855    0.6837
# DummyClassifier                  0.5049             0.5000   0.5000    0.3388
#
#                                Time Taken
# Model
# XGBClassifier                      0.7912
# SVC                                4.1312
# NuSVC                              5.2095
# LGBMClassifier                     0.4118
# AdaBoostClassifier                 0.8522
# LogisticRegression                 0.0766
# CalibratedClassifierCV             5.7559
# LinearSVC                          1.3689
# RandomForestClassifier             1.2992
# BaggingClassifier                  0.7070
# LinearDiscriminantAnalysis         0.1087
# RidgeClassifier                    0.0504
# RidgeClassifierCV                  0.0673
# SGDClassifier                      0.1395
# ExtraTreesClassifier               1.5307
# KNeighborsClassifier               0.3928
# NearestCentroid                    0.0362
# GaussianNB                         0.0394
# BernoulliNB                        0.0530
# LabelSpreading                     7.1861
# LabelPropagation                   5.2013
# Perceptron                         0.0452
# QuadraticDiscriminantAnalysis      0.0698
# DecisionTreeClassifier             0.1034
# ExtraTreeClassifier                0.0616
# PassiveAggressiveClassifier        0.0528
# DummyClassifier                    0.0340

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1739 entries, 0 to 1738
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AdaBoostClassifier             1739 non-null   int32
#  1   BaggingClassifier              1739 non-null   int32
#  2   BernoulliNB                    1739 non-null   int32
#  3   CalibratedClassifierCV         1739 non-null   int32
#  4   DecisionTreeClassifier         1739 non-null   int32
#  5   DummyClassifier                1739 non-null   int32
#  6   ExtraTreeClassifier            1739 non-null   int32
#  7   ExtraTreesClassifier           1739 non-null   int32
#  8   GaussianNB                     1739 non-null   int32
#  9   KNeighborsClassifier           1739 non-null   int32
#  10  LabelPropagation               1739 non-null   int32
#  11  LabelSpreading                 1739 non-null   int32
#  12  LinearDiscriminantAnalysis     1739 non-null   int32
#  13  LinearSVC                      1739 non-null   int32
#  14  LogisticRegression             1739 non-null   int32
#  15  NearestCentroid                1739 non-null   int32
#  16  NuSVC                          1739 non-null   int32
#  17  PassiveAggressiveClassifier    1739 non-null   int32
#  18  Perceptron                     1739 non-null   int32
#  19  QuadraticDiscriminantAnalysis  1739 non-null   int32
#  20  RandomForestClassifier         1739 non-null   int32
#  21  RidgeClassifier                1739 non-null   int32
#  22  RidgeClassifierCV              1739 non-null   int32
#  23  SGDClassifier                  1739 non-null   int32
#  24  SVC                            1739 non-null   int32
#  25  XGBClassifier                  1739 non-null   int32
#  26  LGBMClassifier                 1739 non-null   int32
# dtypes: int32(27)
# memory usage: 183.5 KB
